# %% [markdown]
# <a href="https://colab.research.google.com/github/Hamid8/predicting-house-price/blob/master/Crawler_for_keyword(RTC)2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install advertools

# %%
# !pip install --upgrade advertools

# %%
import advertools as adv

# %% [markdown]
# **1.clawling all  URLs under CSV.com/shop website path**
#
# **2.Download the the RAW data of Crawl**

# %%
adv.crawl('https://get2theroot.com/', 'my_output_file.jl', follow_links=True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-1de10995b44d> in <cell line: 1>()
# ----> 1 adv.crawl('https://get2theroot.com/', 'my_output_file.jl', follow_links=True)
#
# /usr/local/lib/python3.10/dist-packages/advertools/spider.py in crawl(url_list, output_file, follow_links, allowed_domains, exclude_url_params, include_url_params, exclude_url_regex, include_url_regex, css_selectors, xpath_selectors, custom_settings)
#     970             subprocess.run(command)
#     971     else:
# --> 972         subprocess.run(command)
#
# /usr/lib/python3.10/subprocess.py in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     503     with Popen(*popenargs, **kwargs) as process:
#     504         try:
# --> 505             stdout, stderr = process.communicate(input, timeout=timeout)
#     506         except TimeoutExpired as exc:
# ...

# %%
import pandas as pd
crawl_df = pd.read_json('my_output_file.jl', lines=True)

# %%
crawl_df = crawl_df.drop_duplicates('url', keep='last')

# %%
crawl_df = crawl_df.reset_index(drop=True)

# %%
from google.colab import files
crawl_df.to_csv('cvshealth.csv')
files.download('cvshealth.csv')

# %%
crawl_df
# Out:
#                                                      url  \
# 0          https://get2theroot.com/events/month/2023-07/
# 1      https://get2theroot.com/events/list/?tribe-bar...
# 2      https://get2theroot.com/events/list/?tribe-bar...
# 3      https://get2theroot.com/events/list/?tribe-bar...
# 4             https://get2theroot.com/events/2023-08-01/
# ...                                                  ...
# 11670  https://get2theroot.com/events/list/?tribe-bar...
# 11671  https://get2theroot.com/events/list/?tribe-bar...
# 11672  https://get2theroot.com/events/list/?tribe-bar...
# 11673  https://get2theroot.com/events/list/?tribe-bar...
# 11674  https://get2theroot.com/events/list/?tribe-bar...
#
#                                       title meta_desc  \
# 0                Events  - Hope For Healing       NaN
# 1                                       NaN       NaN
# 2                Events  - Hope For Healing       NaN
# 3                                       NaN       NaN
# ...

# %%
crawl_df['url']
# Out:
# 0            https://get2theroot.com/events/month/2023-07/
# 1        https://get2theroot.com/events/list/?tribe-bar...
# 2        https://get2theroot.com/events/list/?tribe-bar...
# 3        https://get2theroot.com/events/list/?tribe-bar...
# 4               https://get2theroot.com/events/2023-08-01/
#                                ...
# 11670    https://get2theroot.com/events/list/?tribe-bar...
# 11671    https://get2theroot.com/events/list/?tribe-bar...
# 11672    https://get2theroot.com/events/list/?tribe-bar...
# 11673    https://get2theroot.com/events/list/?tribe-bar...
# 11674    https://get2theroot.com/events/list/?tribe-bar...
# Name: url, Length: 11675, dtype: object

# %% [markdown]
# ### Checking the table of data with headers and page SEO  and download the file

# %%
meta_dec = crawl_df.dropna(subset = ["meta_desc"], inplace=True)

# %%
meta_dec.to_csv('metadescription.csv')
files.download('metadescription.csv')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-12-5cbc4f3cbf31> in <cell line: 1>()
# ----> 1 meta_dec.to_csv('metadescription.csv')
#       2 files.download('metadescription.csv')
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %% [markdown]
# ###aplying NLP for metadiscription on links

# %%
crawl_df = crawl_df[crawl_df['meta_desc'].notna()]

# %%
crawl_df['meta_desc']
# Out:
# 6445    Hope for Healing is recognized as the top Cert...
# 6446    Learn more from the Hope for Healing team in H...
# 6447    Hope for Healing's Health Coaches help you tak...
# 6448     Frequently Asked Questions and Answers about ...
# 6449    This page lists our favorite and recommended p...
#                               ...
# 6880    Discover the ultimate guide to understanding a...
# 6881    If you're looking for an alternative to tradit...
# 6882    We know finding facts and figures about IV The...
# 6883    I’d like to talk about the foundation, methyla...
# 6885    There has been a growing interest in alternati...
# Name: meta_desc, Length: 245, dtype: object

# %%
import spacy
spacy.cli.download("en_core_web_md")
nlp = spacy.load("en_core_web_md")
# Out:
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_md')

# %% [markdown]
# ##1.remove pounctioation and stop words

# %% [markdown]
# ##2.spacy model tokenize and creating entity column and then detokenize and
#
# ---
#
# ##3.aggregate new in the same date

# %%
crawl_df['meta_desc'] = crawl_df.meta_desc.apply(lambda text:  " ".join(token.lemma_ for token in nlp(text) if not token.is_stop))
crawl_df['meta_desc']  = crawl_df.meta_desc.apply(lambda text:  " ".join(token.lemma_ for token in nlp(text) if not token.is_punct))

# %%
crawl_df['meta_desc'] = crawl_df['meta_desc'].apply(lambda x: nlp(x))

# %%
crawl_df['meta_desc'] = crawl_df['meta_desc'].apply(lambda x: x.text)

# %% [markdown]
# 1. It takes a string as input
# 2. It tokenizes the string using spaCy
# 3. It lemmatizes each token
# 4. It returns a string where each token is separated by a space

# %%
def make_to_base(x):
    x_list = []
    for token in nlp(x):
        lemma=str(token.lemma_)
        if lemma=='-PRON-' or lemma=='be':
            lemma=token.text
        x_list.append(lemma)
    return " ".join(x_list)

# %%
crawl_df['meta_desc'] =  crawl_df['meta_desc'].apply(lambda x: make_to_base(x))

# %%
x =' '.join(crawl_df.meta_desc)

# %%
xy = str(x)
z =  xy.split()

# %%
z
# Out:
# ['Hope',
#  'Healing',
#  'recognize',
#  'Certified',
#  'Functional',
#  'Medicine',
#  'Practioner',
#  'focus',
#  'root',
#  'cause',
#  'issue',
#  'find',
#  'permanent',
#  'solution',
#  'begin',
#  'journey',
#  'Health',
#  'Wellness',
#  'learn',
#  'Hope',
#  'Healing',
#  'team',
#  'Houston',
#  'Shenandoah',
#  'Certified',
#  'Functional',
#  'Medicine',
#  'Practioner',
#  'focus',
#  'root',
#  'cause',
#  'issue',
#  'find',
#  'permanent',
#  'solution',
#  'join',
#  'Journey',
#  'Health',
#  'Wellness',
#  'Hope',
#  'Healing',
#  'Health',
#  'Coaches',
#  'help',
#  'control',
#  'health',
#  'wellness',
#  'learn',
#  'coach',
#  'frequently',
#  'ask',
#  'question',
#  'answer',
#  'Hope',
#  'Healing',
#  'New',
#  'Patients',
#  'IV',
#  'Therapy',
#  'ozone',
#  'Therapy',
#  'page',
#  'list',
#  'favorite',
#  'recommend',
#  'product',
#  'patient',
#  'enjoy',
#  'begin',
#  'journey',
#  'Health',
#  'Wellness',
#  'start',
#  'journey',
# ...

# %% [markdown]
# count the distiboution of words

# %%
count = crawl_df.groupby(['meta_desc']).count()

# %%
df200 = pd.DataFrame(columns = ['word', 'frequency'])

# %%
import numpy as np

# %%
df200=pd.Series(np.concatenate([x.split() for x in crawl_df.meta_desc])).value_counts()[10:20]

# %%
df200.index
# Out:
# Index(['medicine', 'Texas', 'good', 'help', 'parent', 'integrative', 'provide',
#        'Houston', 'holistic', 'explore'],
#       dtype='object')

# %%
import plotly.express as px

# %% [markdown]
# ## data visulization

# %%
fig = px.bar(df200, x=df200.index,y=df200,title="Top 10 frequent  Words in Meta decription frequent ", labels={"y": "Count", "x": "Top 10 Words Stems"},
              )
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
